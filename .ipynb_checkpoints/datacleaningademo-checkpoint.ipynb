# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
getdatawithheader1 = pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)

# %%
getdatawithheader1
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
barplot = getdatawithheader[['Qty Loomis','Qty Bank','Qty Var']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f8084d9a1cde> in <module>
# ----> 1 barplot = getdatawithheader[['Qty Loomis','Qty Bank','Qty Var']]
#
# NameError: name 'getdatawithheader' is not defined

# %%
barplot = getdatawithheader1['Qty Loomis','Qty Bank','Qty Var']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Qty Loomis', 'Qty Bank', 'Qty Var')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-6-f6c6ead0c7f0> in <module>
# ...

# %%
barplot = getdatawithheader1[['Qty Loomis','Qty Bank','Qty Var']]

# %%
barplot
# Out:
#            Qty Loomis  Qty Bank  Qty Var
# Security
# 042735BC3       19999     20008       -9
# 717081103         399       455      -56
# 92826C839         199       600     -401
# 02079K107         509     99988   -99479
# 31162100          996       779      217
# 03523TBP2       19999     20000       -1

# %%
qtyvar =  getdatawithheader1['Qty Var'] > abs(100)

# %%
qtyvar =  getdatawithheader1['Qty Var'] > abs(1001)

# %%
qtyvar
# Out:
# Security
# 042735BC3    False
# 717081103    False
# 92826C839    False
# 02079K107    False
# 31162100     False
# 03523TBP2    False
# Name: Qty Var, dtype: bool

# %%
qtyvar1 =  getdatawithheader1['Qty Var'] > 100

# %%
qtyvar2 =  getdatawithheader1['Qty Var'] < 1000

# %%
var = [qtyvar1 | qtyvar2]

# %%
var
# Out:
# [Security
#  042735BC3    True
#  717081103    True
#  92826C839    True
#  02079K107    True
#  31162100     True
#  03523TBP2    True
#  Name: Qty Var, dtype: bool]

# %%
qty = getdatawithheader['Qty Var'] > 1000
bank = getdatawithheader['Qty Bank'] > 2000
getdatawithheader[qty]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-bdfaa4ff6735> in <module>
# ----> 1 qty = getdatawithheader['Qty Var'] > 1000
#       2 bank = getdatawithheader['Qty Bank'] > 2000
#       3 getdatawithheader[qty]
#
# NameError: name 'getdatawithheader' is not defined

# %%
qty = getdatawithheader1['Qty Var'] > 1000
bank = getdatawithheader1['Qty Bank'] > 2000
getdatawithheader[qty]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-0b7521e5eced> in <module>
#       1 qty = getdatawithheader1['Qty Var'] > 1000
#       2 bank = getdatawithheader1['Qty Bank'] > 2000
# ----> 3 getdatawithheader[qty]
#
# NameError: name 'getdatawithheader' is not defined

# %%
qty = getdatawithheader1['Qty Var'] > 1000
bank = getdatawithheader1['Qty Bank'] > 2000
getdatawithheader1[qty]
# Out:
# Empty DataFrame
# Columns: [Loomis_Account_Name,  Bank Account, Break Type-Separate Accounts, Description, Local Curr, Qty Loomis, Qty Bank, Qty Var, Local Prc Loomis,   Local Prc Bank , Prc Var (%), Base MV Loomis, Base MV Bank, MV Var, MV Var(%), Base Cost Loomis, Base Cost  Bank, Cost Var, Base Accr Loomis, Base Accr Bank, Accr Var (%), Basis_Pt (%), Comment]
# Index: []
#
# [0 rows x 23 columns]

# %%
qty = getdatawithheader1['Qty Var'] < 1000
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
qty = getdatawithheader1['Qty Var'] < -1000
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 02079K107                efgi         4567y                  Outstanding
#
#                  Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 02079K107  ALPHABET INC-CL C         NaN         509     99988   -99479
#
#            Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                         ...
# 02079K107               NaN            1188.48   ...          0          0
#
#            Base Cost Loomis  Base Cost  Bank  Cost Var  Base Accr Loomis  \
# Security
# 02079K107                 0                0         0                 0
#
#            Base Accr Bank  Accr Var (%)  Basis_Pt (%)  Comment
# Security
# 02079K107               0             0             0      NaN
#
# [1 rows x 23 columns]

# %%
qty = getdatawithheader1['Qty Var'] < abs(200)
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# 03523TBP2  ANHEUSER-BUSCH INBEV WOR20220715         NaN       19999     20000
#
# ...

# %%
qty = getdatawithheader1['Qty Var'] < abs(400)
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
qty = getdatawithheader1['Qty Var'] > abs(400)
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
# Empty DataFrame
# Columns: [Loomis_Account_Name,  Bank Account, Break Type-Separate Accounts, Description, Local Curr, Qty Loomis, Qty Bank, Qty Var, Local Prc Loomis,   Local Prc Bank , Prc Var (%), Base MV Loomis, Base MV Bank, MV Var, MV Var(%), Base Cost Loomis, Base Cost  Bank, Cost Var, Base Accr Loomis, Base Accr Bank, Accr Var (%), Basis_Pt (%), Comment]
# Index: []
#
# [0 rows x 23 columns]

# %%
qty = getdatawithheader1['Qty Var'] > abs(200)
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
#          Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 31162100                efgr         4567f                  Outstanding
#
#          Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 31162100   AMGEN INC         NaN         996       779      217
#
#           Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                        ...
# 31162100               NaN             179.32   ...          0          0
#
#           Base Cost Loomis  Base Cost  Bank  Cost Var  Base Accr Loomis  \
# Security
# 31162100                 0                0         0                 0
#
#           Base Accr Bank  Accr Var (%)  Basis_Pt (%)  Comment
# Security
# 31162100               0             0             0      NaN
#
# [1 rows x 23 columns]

# %%
qty = getdatawithheader1['Qty Var'] > 200 | < 200 
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty]
# Out:
#   File "<ipython-input-25-a1a86ebfdf8f>", line 1
#     qty = getdatawithheader1['Qty Var'] > 200 | < 200
#                                                 ^
# SyntaxError: invalid syntax

# %%
qty = getdatawithheader1['Qty Var'] < -20
qty2 = getdatawithheader1['Qty Var'] > 200
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty, qty2  ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-5856157d3c1a> in <module>
#       2 qty2 = getdatawithheader1['Qty Var'] > 200
#       3 bank = getdatawithheader1['Qty Bank'] > 200
# ----> 4 getdatawithheader1[qty, qty2  ]
#
# c:\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\python36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
qty = getdatawithheader1['Qty Var'] < -20
qty2 = getdatawithheader1['Qty Var'] > 200
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty | qty2  ]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
#
#                      Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 717081103             PFIZER INC         NaN         399       455      -56
# 92826C839  VISA INC-CLASS A SHRS         NaN         199       600     -401
# 02079K107      ALPHABET INC-CL C         NaN         509     99988   -99479
# 31162100               AMGEN INC         NaN         996       779      217
#
#            Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                         ...
# ...

# %%
qty = getdatawithheader1['Qty Var'] < -200
qty2 = getdatawithheader1['Qty Var'] > 200
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty | qty2  ]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
#
#                      Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 92826C839  VISA INC-CLASS A SHRS         NaN         199       600     -401
# 02079K107      ALPHABET INC-CL C         NaN         509     99988   -99479
# 31162100               AMGEN INC         NaN         996       779      217
#
#            Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                         ...
# 92826C839               NaN             164.43   ...          0          0
# 02079K107               NaN            1188.48   ...          0          0
# ...

# %%
qty = getdatawithheader1['Qty Var'] < -200
qty2 = getdatawithheader1['Qty Var'] > 200
bank = getdatawithheader1['Qty Bank'] > 200
getdatawithheader1[qty | qty2 | bank ]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
qtyr = 'Qty Var'
bankr = 'Qty Bank'

# %%
getdatawithheader1[[qtyr,bankr]]
# Out:
#            Qty Var  Qty Bank
# Security
# 042735BC3       -9     20008
# 717081103      -56       455
# 92826C839     -401       600
# 02079K107   -99479     99988
# 31162100       217       779
# 03523TBP2       -1     20000

# %%
# %matplotlib notebook

# %%
matplot = getdatawithheader1[[qtyr,bankr]]

# %%
matplot.bar
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-c1b32805d568> in <module>
# ----> 1 matplot.bar
#
# c:\python36\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'bar'

# %%
matplot.plot.bar
# Out:
# <bound method FramePlotMethods.bar of <pandas.plotting._core.FramePlotMethods object at 0x00000198CE8E61D0>>

# %%
matplot.plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="639.9967956703402">
