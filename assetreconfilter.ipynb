# %%
print(rec) = pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)
# Out:
#   File "<ipython-input-1-7c0e15bf7908>", line 1
#     print(rec) = pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)
#                                                                                                    ^
# SyntaxError: can't assign to function call

# %%
rec = pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-09d0f04014dc> in <module>
# ----> 1 rec = pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
rec = pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)

# %%
print(rec)
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
rec
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
rec = rec['Qty Var']>0

# %%
rec
# Out:
# Security
# 042735BC3    False
# 717081103    False
# 92826C839    False
# 02079K107    False
# 31162100      True
# 03523TBP2    False
# Name: Qty Var, dtype: bool

# %%
rec1 = rec[rec('Qty Var')]>0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-511c3f996dea> in <module>
# ----> 1 rec1 = rec[rec('Qty Var')]>0
#
# TypeError: 'Series' object is not callable

# %%
ouroftlerance1 = rec['Qty Var'] < -200
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\python36\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    3123             try:
# -> 3124                 return libindex.get_value_box(s, key)
#    3125             except IndexError:
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# pandas\_libs\index.pyx in pandas._libs.index.get_value_box()
#
# TypeError: 'str' object cannot be interpreted as an integer
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-f14372c359f8> in <module>
# ----> 1 ouroftlerance1 = rec['Qty Var'] < -200
#
# c:\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     765         key = com._apply_if_callable(key, self)
#     766         try:
# ...

# %%
rec
# Out:
# Security
# 042735BC3    False
# 717081103    False
# 92826C839    False
# 02079K107    False
# 31162100      True
# 03523TBP2    False
# Name: Qty Var, dtype: bool

# %%
data =  pd.read_csv('pandadatarecthis.csv', skiprows=[0,1,2,3], index_col = 3, header = 0)

# %%
data
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
ouroftlerance1 = data['Qty Var'] < -200

# %%
ouroftlerance1
# Out:
# Security
# 042735BC3    False
# 717081103    False
# 92826C839     True
# 02079K107     True
# 31162100     False
# 03523TBP2    False
# Name: Qty Var, dtype: bool

# %%
ouroftlerance1[data]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f643fffa2428> in <module>
# ----> 1 ouroftlerance1[data]
#
# c:\python36\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     808             key = check_bool_indexer(self.index, key)
#     809
# --> 810         return self._get_with(key)
#     811
#     812     def _get_with(self, key):
#
# c:\python36\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     816             return self._get_values(indexer)
#     817         elif isinstance(key, ABCDataFrame):
# --> 818             raise TypeError('Indexing a Series with DataFrame is not '
#     819                             'supported, use the appropriate DataFrame column')
#     820         else:
#
# TypeError: Indexing a Series with DataFrame is not supported, use the appropriate DataFrame column

# %%
data[data]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-69b1bb2a6270> in <module>
# ----> 1 data[data]
#
# c:\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2682             return self._getitem_array(key)
#    2683         elif isinstance(key, DataFrame):
# -> 2684             return self._getitem_frame(key)
#    2685         elif is_mi_columns:
#    2686             return self._getitem_multilevel(key)
#
# c:\python36\lib\site-packages\pandas\core\frame.py in _getitem_frame(self, key)
#    2765     def _getitem_frame(self, key):
#    2766         if key.values.size and not is_bool_dtype(key.values):
# -> 2767             raise ValueError('Must pass DataFrame with boolean values only')
#    2768         return self.where(key)
#    2769
#
# ValueError: Must pass DataFrame with boolean values only

# %%
data[ouroftlerance1]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
#
#                      Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 92826C839  VISA INC-CLASS A SHRS         NaN         199       600     -401
# 02079K107      ALPHABET INC-CL C         NaN         509     99988   -99479
#
#            Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                         ...
# 92826C839               NaN             164.43   ...          0          0
# 02079K107               NaN            1188.48   ...          0          0
#
#            Base Cost Loomis  Base Cost  Bank  Cost Var  Base Accr Loomis  \
# Security
# 92826C839                 0                0         0                 0
# ...

# %%
ouroftlerance2 = data['Qty Var'] !=0

# %%
ouroftlerance2
# Out:
# Security
# 042735BC3    True
# 717081103    True
# 92826C839    True
# 02079K107    True
# 31162100     True
# 03523TBP2    True
# Name: Qty Var, dtype: bool

# %%
ouroftlerance2 = data['Qty Var'] !=199

# %%
ouroftlerance2
# Out:
# Security
# 042735BC3    True
# 717081103    True
# 92826C839    True
# 02079K107    True
# 31162100     True
# 03523TBP2    True
# Name: Qty Var, dtype: bool

# %%
data[ouroftlerance2]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...

# %%
data[ouroftlerance1]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
#
#                      Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 92826C839  VISA INC-CLASS A SHRS         NaN         199       600     -401
# 02079K107      ALPHABET INC-CL C         NaN         509     99988   -99479
#
#            Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                         ...
# 92826C839               NaN             164.43   ...          0          0
# 02079K107               NaN            1188.48   ...          0          0
#
#            Base Cost Loomis  Base Cost  Bank  Cost Var  Base Accr Loomis  \
# Security
# 92826C839                 0                0         0                 0
# ...

# %%
data[ouroftlerance1, ouroftlerance2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-b7cdb23be930> in <module>
# ----> 1 data[ouroftlerance1, ouroftlerance2]
#
# c:\python36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# c:\python36\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# c:\python36\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2485         """Return the cached item, item represents a label indexer."""
# ...

# %%
data[ouroftlerance1 & ouroftlerance2]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
#
#                      Description  Local Curr  Qty Loomis  Qty Bank  Qty Var  \
# Security
# 92826C839  VISA INC-CLASS A SHRS         NaN         199       600     -401
# 02079K107      ALPHABET INC-CL C         NaN         509     99988   -99479
#
#            Local Prc Loomis    Local Prc Bank    ...     MV Var  MV Var(%)  \
# Security                                         ...
# 92826C839               NaN             164.43   ...          0          0
# 02079K107               NaN            1188.48   ...          0          0
#
#            Base Cost Loomis  Base Cost  Bank  Cost Var  Base Accr Loomis  \
# Security
# 92826C839                 0                0         0                 0
# ...

# %%
data[ouroftlerance1 | ouroftlerance2]
# Out:
#           Loomis_Account_Name  Bank Account Break Type-Separate Accounts  \
# Security
# 042735BC3                abca         1234a                  Outstanding
# 717081103                abcd         1234g                  Outstanding
# 92826C839                abce         1234a                  Outstanding
# 02079K107                efgi         4567y                  Outstanding
# 31162100                 efgr         4567f                  Outstanding
# 03523TBP2                efgw         4567b                  Outstanding
#
#                                 Description  Local Curr  Qty Loomis  Qty Bank  \
# Security
# 042735BC3     ARROW ELECTRONICS INC20230301         NaN       19999     20008
# 717081103                        PFIZER INC         NaN         399       455
# 92826C839             VISA INC-CLASS A SHRS         NaN         199       600
# 02079K107                 ALPHABET INC-CL C         NaN         509     99988
# ...
