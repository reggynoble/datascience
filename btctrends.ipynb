# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
plt.style.use('ggplot')

# %%
#Date","Price","Open","High","Low","Vol.","Change %

fig =plt.figure()

# %%
data = pd.read_csv('BTC_USD_Bitfinex_Historical_Data.csv', header = 0)

# %%
data
# Out:
#             Date    Price     Open     High      Low    Vol. Change %
# 0   Jun 15, 2019  8,869.0  8,689.0  8,904.1  8,611.0   9.37K    2.07%
# 1   Jun 14, 2019  8,689.1  8,230.0  8,714.9  8,163.3  12.71K    5.61%
# 2   Jun 13, 2019  8,227.4  8,177.6  8,333.0  8,038.9   8.89K    0.64%
# 3   Jun 12, 2019  8,175.4  7,903.1  8,238.8  7,822.3   9.14K    3.43%
# 4   Jun 11, 2019  7,904.1  8,018.8  8,048.9  7,711.3   6.53K   -1.37%
# 5   Jun 10, 2019  8,013.7  7,622.5  8,046.3  7,523.3   8.90K    4.90%
# 6   Jun 09, 2019  7,639.2  7,924.0  7,961.0  7,502.5   6.83K   -3.60%
# 7   Jun 08, 2019  7,924.6  8,002.1  8,064.8  7,802.0   4.77K   -0.84%
# 8   Jun 07, 2019  7,991.5  7,816.9  8,123.5  7,769.1  13.44K    2.38%
# 9   Jun 06, 2019  7,805.6  7,766.3  7,870.6  7,461.0   7.51K    0.21%
# 10  Jun 05, 2019  7,789.3  7,692.8  7,931.0  7,603.0  10.83K    1.25%
# 11  Jun 04, 2019  7,692.8  8,088.0  8,088.0  7,524.5  28.12K   -5.07%
# ...

# %%
Date = data['Date']

# %%
Date
# Out:
# 0     Jun 15, 2019
# 1     Jun 14, 2019
# 2     Jun 13, 2019
# 3     Jun 12, 2019
# 4     Jun 11, 2019
# 5     Jun 10, 2019
# 6     Jun 09, 2019
# 7     Jun 08, 2019
# 8     Jun 07, 2019
# 9     Jun 06, 2019
# 10    Jun 05, 2019
# 11    Jun 04, 2019
# 12    Jun 03, 2019
# 13    Jun 02, 2019
# 14    Jun 01, 2019
# 15    May 31, 2019
# 16    May 30, 2019
# 17    May 29, 2019
# 18    May 28, 2019
# 19    May 27, 2019
# 20    May 26, 2019
# 21    May 25, 2019
# 22    May 24, 2019
# 23    May 23, 2019
# 24    May 22, 2019
# 25    May 21, 2019
# 26    May 20, 2019
# 27    May 19, 2019
# 28    May 18, 2019
# 29    May 17, 2019
# 30    May 16, 2019
# 31    May 15, 2019
# Name: Date, dtype: object

# %%
prices = data['Price']

# %%
prices
# Out:
# 0     8,869.0
# 1     8,689.1
# 2     8,227.4
# 3     8,175.4
# 4     7,904.1
# 5     8,013.7
# 6     7,639.2
# 7     7,924.6
# 8     7,991.5
# 9     7,805.6
# 10    7,789.3
# 11    7,692.8
# 12    8,103.4
# 13    8,740.0
# 14    8,547.0
# 15    8,533.3
# 16    8,269.9
# 17    8,680.9
# 18    8,740.9
# 19    8,806.0
# 20    8,729.9
# 21    8,054.9
# 22    7,994.9
# 23    7,872.4
# 24    7,621.1
# 25    7,937.0
# 26    7,985.0
# 27    8,189.5
# 28    7,260.0
# 29    7,415.4
# 30    7,857.0
# 31    8,132.9
# Name: Price, dtype: object

# %%
prices[9]
# Out:
# '7,805.6'

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
fig, axes = plt.subplots(2,1)
# Out:
# <img src="data:image/png;base64,..." width="639.2025602824718">

# %%
btctrends = data[['Date', 'Price']]

# %%
btctrends
# Out:
#             Date    Price
# 0   Jun 15, 2019  8,869.0
# 1   Jun 14, 2019  8,689.1
# 2   Jun 13, 2019  8,227.4
# 3   Jun 12, 2019  8,175.4
# 4   Jun 11, 2019  7,904.1
# 5   Jun 10, 2019  8,013.7
# 6   Jun 09, 2019  7,639.2
# 7   Jun 08, 2019  7,924.6
# 8   Jun 07, 2019  7,991.5
# 9   Jun 06, 2019  7,805.6
# 10  Jun 05, 2019  7,789.3
# 11  Jun 04, 2019  7,692.8
# 12  Jun 03, 2019  8,103.4
# 13  Jun 02, 2019  8,740.0
# 14  Jun 01, 2019  8,547.0
# 15  May 31, 2019  8,533.3
# 16  May 30, 2019  8,269.9
# 17  May 29, 2019  8,680.9
# 18  May 28, 2019  8,740.9
# 19  May 27, 2019  8,806.0
# 20  May 26, 2019  8,729.9
# 21  May 25, 2019  8,054.9
# 22  May 24, 2019  7,994.9
# 23  May 23, 2019  7,872.4
# 24  May 22, 2019  7,621.1
# 25  May 21, 2019  7,937.0
# 26  May 20, 2019  7,985.0
# 27  May 19, 2019  8,189.5
# 28  May 18, 2019  7,260.0
# 29  May 17, 2019  7,415.4
# 30  May 16, 2019  7,857.0
# 31  May 15, 2019  8,132.9

# %%
from bokeh.io import show, output_notebook
from bokeh.models import CategoricalColorMapper, ColumnDataSource, FactorRange
from bokeh.plotting import figure

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ab497b27-8054-4f23-b766-ed566c823251">Loading BokehJS ...</span>
#     </div>

# %%
dates = data[['Date']]

# %%
prices = data[['Price']]

# %%
from bokeh.plotting import figure, output_file, show

plot = figure(plot_width=300, plot_height=300)
plot.vbar(x=dates, width=0.5, bottom=0, top=prices, color="#CAB2D6")

show(plot)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-9997b9db78b6> in <module>
#       2
#       3 plot = figure(plot_width=300, plot_height=300)
# ----> 4 plot.vbar(x=dates, width=0.5, bottom=0, top=prices, color="#CAB2D6")
#       5
#       6 show(plot)
#
# NameError: name 'dates' is not defined

# %%
dates = data[['Date']]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a780892cda22> in <module>
# ----> 1 dates = data[['Date']]
#
# NameError: name 'data' is not defined

# %%
data = pd.read_csv('BTC_USD_Bitfinex_Historical_Data.csv', header = 0)

# %%
dates = data[['Date']]

# %%
dates
# Out:
#             Date
# 0   Jun 15, 2019
# 1   Jun 14, 2019
# 2   Jun 13, 2019
# 3   Jun 12, 2019
# 4   Jun 11, 2019
# 5   Jun 10, 2019
# 6   Jun 09, 2019
# 7   Jun 08, 2019
# 8   Jun 07, 2019
# 9   Jun 06, 2019
# 10  Jun 05, 2019
# 11  Jun 04, 2019
# 12  Jun 03, 2019
# 13  Jun 02, 2019
# 14  Jun 01, 2019
# 15  May 31, 2019
# 16  May 30, 2019
# 17  May 29, 2019
# 18  May 28, 2019
# 19  May 27, 2019
# 20  May 26, 2019
# 21  May 25, 2019
# 22  May 24, 2019
# 23  May 23, 2019
# 24  May 22, 2019
# 25  May 21, 2019
# 26  May 20, 2019
# 27  May 19, 2019
# 28  May 18, 2019
# 29  May 17, 2019
# 30  May 16, 2019
# 31  May 15, 2019

# %%
prices = data[['Price']]

# %%
prices
# Out:
#      Price
# 0   8869.0
# 1   8689.1
# 2   8227.4
# 3   8175.4
# 4   7904.1
# 5   8013.7
# 6   7639.2
# 7   7924.6
# 8   7991.5
# 9   7805.6
# 10  7789.3
# 11  7692.8
# 12  8103.4
# 13  8740.0
# 14  8547.0
# 15  8533.3
# 16  8269.9
# 17  8680.9
# 18  8740.9
# 19  8806.0
# 20  8729.9
# 21  8054.9
# 22  7994.9
# 23  7872.4
# 24  7621.1
# 25  7937.0
# 26  7985.0
# 27  8189.5
# 28  7260.0
# 29  7415.4
# 30  7857.0
# 31  8132.9

# %%
from bokeh.plotting import figure, output_file, show

plot = figure(plot_width=800, plot_height=800)
plot.vbar(x=dates, width=0.5, bottom=0, top=prices, color="#CAB2D6")

show(plot)

# %%
from bokeh.plotting import figure, output_file, show

plot = figure(plot_width=800, plot_height=800)
plot.vbar(x=dates, width=0.5, bottom=0, top=prices, color="#CAB2D6")

show(plot)

# %%
data = pd.read_csv('BTC_USD_Bitfinex_Historical_Data.csv', header = 0)

# %%
data
# Out:
#             Date   Price    Open    High     Low    Vol. Change %
# 0   Jun 15, 2019  8869.0  8689.0  8904.1  8611.0   9.37K    2.07%
# 1   Jun 14, 2019  8689.1  8230.0  8714.9  8163.3  12.71K    5.61%
# 2   Jun 13, 2019  8227.4  8177.6  8333.0  8038.9   8.89K    0.64%
# 3   Jun 12, 2019  8175.4  7903.1  8238.8  7822.3   9.14K    3.43%
# 4   Jun 11, 2019  7904.1  8018.8  8048.9  7711.3   6.53K   -1.37%
# 5   Jun 10, 2019  8013.7  7622.5  8046.3  7523.3   8.90K    4.90%
# 6   Jun 09, 2019  7639.2  7924.0  7961.0  7502.5   6.83K   -3.60%
# 7   Jun 08, 2019  7924.6  8002.1  8064.8  7802.0   4.77K   -0.84%
# 8   Jun 07, 2019  7991.5  7816.9  8123.5  7769.1  13.44K    2.38%
# 9   Jun 06, 2019  7805.6  7766.3  7870.6  7461.0   7.51K    0.21%
# 10  Jun 05, 2019  7789.3  7692.8  7931.0  7603.0  10.83K    1.25%
# 11  Jun 04, 2019  7692.8  8088.0  8088.0  7524.5  28.12K   -5.07%
# 12  Jun 03, 2019  8103.4  8740.1  8740.1  8050.1  18.66K   -7.28%
# ...
